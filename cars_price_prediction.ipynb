# %% [markdown]
# <a href="https://colab.research.google.com/github/LeidyGal/Seminario-BigData/blob/main/cars_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cars price prediction
# [Author: Elias Buitrago Bolivar](https://github.com/ebuitrago?tab=repositories)
#
# The objective of this jupyter notebook is to train a machine learning algorithm to predict a car's price, based on known characteristics. The training data was obtained by web scraping, using Selenium and Beautiful Soap from tucarro.com.co; This project has no commercial purposes its for merely academic endeavor.
# _Updated: June 22th, 2024_

# %% [markdown]
# ## Data understanding

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ### Load data

# %%
cols = ['model','price','year','kms','color','fueltype']
data = pd.read_csv('/content/drive/MyDrive/data/usedCarsCol_spark_200624.csv', sep=',', names=cols, header=0, encoding='latin-1')
print(data.shape)
data.head()
# Out:
# (430, 6)
#                                 model        price  year     kms  \
# 0          Chevrolet Spark Gt Gt Full  $32.500.000  2017  103.06
# 1              Chevrolet Spark Gt Ltz  $34.700.000  2017   72.40
# 2  Chevrolet Captiva 2.4 Sport 182 hp  $37.500.000  2016   62.00
# 3              Chevrolet Spark Gt Ltz  $34.500.000  2016   46.10
# 4          Chevrolet Spark GT 1.2 Ltz  $41.900.000  2021   18.00
#
#              color  fueltype
# 0  Color not found  Gasolina
# 1  Color not found  Gasolina
# 2            Negro  Gasolina
# 3             Gris  Gasolina
# 4           Blanco  Gasolina

# %% [markdown]
# ### Verify data types

# %%
data.dtypes
# Out:
# model        object
# price        object
# year          int64
# kms         float64
# color        object
# fueltype     object
# dtype: object

# %% [markdown]
# ### Count unique values for each variable

# %%
data.nunique()
# Out:
# model       113
# price       145
# year         18
# kms         274
# color        11
# fueltype      2
# dtype: int64

# %%
print(data['model'].unique().tolist())
print(data['price'].unique().tolist())
print(data['year'].unique().tolist())
print(data['kms'].unique().tolist())
print(data['color'].unique().tolist())
print(data['fueltype'].unique().tolist())
# Out:
# ['Chevrolet Spark Gt Gt Full', 'Chevrolet Spark Gt Ltz', 'Chevrolet Captiva 2.4 Sport 182 hp', 'Chevrolet Spark GT 1.2 Ltz', 'Chevrolet Spark LT LIFE', 'Chevrolet Spark 1.2 Gt M300 Ltz MecÃ¡nica', 'Chevrolet Spark 1.0 7:24 Cronos', 'Chevrolet Spark Gt Mod 2017', 'Chevrolet Spark 1.0 Life', 'Chevrolet Spark 1.2 Gt M300 Ltz', 'Chevrolet Spark 1.2 Gt M300 Lt', 'Chevrolet Spark 1.0 Go', 'Chevrolet Spark Life', 'Chevrolet Spark 1.2 GT LTZ/PREMIER MT', 'Chevrolet Spark Gt Lt Cc1200 Mecanico 80 Hp', 'Chevrolet Spark 1.2 GT ACTIV MT', 'Chevrolet Spark GT 1.2', 'Chevrolet Spark 1.2 Gt M300', 'Chevrolet Spark 1.0 Life Lujo', 'Chevrolet Spark Gt Activ 2022', 'Chevrolet Spark 1.2 Gt Lt', 'Chevrolet Spark LIFE', 'Chevrolet Spark Lt 2013', 'Chevrolet Spark Gt', 'Chevrolet Spark 1.2 Gt Ltz', 'Chevrolet Spark 1.0 Lt M200', 'Chevrolet Spark 2014', 'Chevrolet Spark GT lt 1.2', 'Chevrolet Spark Gt Gt Ltz ', 'Chevrolet Spark Life 1.0 2019', 'Chevrolet Spark Gt Ltz 1.2 Mt Mod 2012 ', 'Chevrolet Spark 1.2 Gt Ls', 'Chevrolet Spark 1.0 Life Go Techo Corredizo', 'Chevrolet Spark gt 1.2', 'Chevrolet Spark Gt Active 2020', 'Chevrolet Spark Gt Ltz 2015', 'Chevrolet Spark Gt Ltz 2016', 'Chevrolet Spark Gt Activ Cc1200 Mecanico 80 Hp', 'Chevrolet Spark Gt Lts 1.2 5p 2017 Jdr247', 'Chevrolet Spark Gt Lt Mt Modelo 2018', 'Chevrolet Spark GT 1.206 Ls Mecanico', ' Chevrolet Spark Gt Active 2022', 'Chevrolet Spark 1.0 Ls', 'Chevrolet Spark GT 1.2 Active', 'Chevrolet Spark Gt Spark Gt Ltz', 'Chevrolet Spark Gt 2017', 'Spark Gt Ltz', 'Spark Gt Ltz 1.2', 'Chevrolet Spark Gt Gt', 'Chevrolet Spark Gt Spark Gt Ltz Mec 1.4', 'Chevrolet Spark GT 1.2 Ls', 'Chevrolet Spark GT LT 1.2 MT', 'Chevrolet Spark Gt Modelo 2015 2 DueÃ±o Buen Estado 1200cm3.', 'Chevrolet Spark Spark life ls 2015 con aire', 'Chevrolet Spark Gt 2017 Ltz 1200cc Mecanico Full ', 'Chevrolet Spark Gt 2015', 'Chevrolet Spark', 'Chevrolet Spark Gt Ltz 2013', 'Chevrolet Spark Gt Gt 1.2', 'Chevrolet Spark Ltz', 'Chevrolet Spark Gt 2011', 'Chevrolet Spark Gt 1.2', 'Chevrolet Spark Gt 1.2 Ltz', 'Chevrolet Spark Coopebombas 2014', 'Chevrolet Spark GT LS 1.2', 'Chevrolet  Spark  Gt  Ltz   2016', 'Chevrolet Spark Gt Active 2022', 'Chevrolet Spark GT 1.2 Lt', 'Chevrolet Spark Gt Ltz 2017 Con 77 Mil Km', 'Chevrolet Spark 1.0l', 'Chevrolet Sparkgt', 'Chevrolet Spark Gt 2013', 'Spark Gt Modelo 2013 VersiÃ³n Full', 'Chevrolet Spark Gt Mt', 'Chevrolet Spark Gt La VersiÃ³n MÃ¡s Full ', 'Chevrolet Spark Gt Spark Gt ', 'Chevrolet Spark Gt Spark Gt', 'Chevrolet Spark Gt Full', 'Chevrolet Spark 1.0 7:24', 'Chevrolet Spark Gt Lt', 'Chevrolet Spark 1.0', 'Chevrolet Aveo', 'Chevrolet Spark Gt Full Equipo', 'Chevrolet Spark Gt Full Equipo ', 'Chevrolet Spark Gt Activ ', 'Taxi - Modelo 2019', 'Chevrolet Spark Lt', 'Chevrolet Spark 995 Cc', 'Spark Gt', 'Chevrolet Spark Gt Version Full Equipo ', 'Chevrolet Spark Gt Modelo 2015 Color Rojo', 'Chevrolet Spark Gt - 2017', 'Chevrolet Spark Gt 2014', 'Chevrolet Spark Gt 2014 Full Equipo', 'Chevr
# ['Color not found', 'Negro', 'Gris', 'Blanco', 'Rojo', 'Verde', 'Plateado', 'Azul', 'MarrÃ³n', 'Dorado', 'Amarillo']
# ['Gasolina', 'Gasolina y gas']

# %% [markdown]
# ### Data transformation

# %%
# Copy data and remove model variable
datacc = data
datacc = datacc.drop(['model'], axis=1)
datacc.shape
# Out:
# (430, 5)

# %% [markdown]
# #### Transform $price$ to numerical

# %%
datacc['price'] = datacc['price'].str.replace(r'[$.]', '', regex=True).astype(int)

# %% [markdown]
# ##### Transform $kms$ to numerical

# %%
#como el datatype de la variable 'kms' esta como float se convierte a str
datacc['kms'] = datacc['kms'].astype(str)
datacc['kms'] = datacc['kms'].str.replace(r'[.]', '',regex=True).astype(int)

# %%
datacc.replace({'kms': {'Publicado': 0}}, inplace=True)

# %%
datacc['kms'] = datacc['kms'].replace('[.]','',regex=True).astype(int)

# %% [markdown]
# ##### Transform categorical variables to dummies: $year$ and $fuel type$

# %%
# Object to categorical
datacc['color'] = datacc['color'].astype('category')
datacc['fueltype'] = datacc['fueltype'].astype('category')
datacc.dtypes
# Out:
# price          int64
# year           int64
# kms            int64
# color       category
# fueltype    category
# dtype: object

# %%
# Convert to dummies
# Convert category to codes
datacc['color']  = pd.Categorical(datacc['color']).codes
datacc['fueltype']  = pd.Categorical(datacc['fueltype']).codes
datacc.head()
# Out:
#       price  year    kms  color  fueltype
# 0  32500000  2017  10306      3         0
# 1  34700000  2017    724      3         0
# 2  37500000  2016    620      7         0
# 3  34500000  2016    461      5         0
# 4  41900000  2021    180      2         0

# %% [markdown]
# ## Data Exploration

# %%
# Descriptive statistics
datacc.describe()[['price','year','kms']]
# Out:
#               price         year            kms
# count  4.300000e+02   430.000000     430.000000
# mean   2.940522e+07  2015.130233   16370.402326
# std    7.218838e+06     3.356345   43821.617642
# min    1.049000e+07  2005.000000       0.000000
# 25%    2.392500e+07  2013.000000     760.000000
# 50%    2.900000e+07  2015.000000    1050.000000
# 75%    3.415000e+07  2018.000000    1627.500000
# max    7.000000e+07  2022.000000  416473.000000

# %% [markdown]
# #### Histograms

# %%
# Histograms
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,6))
fig.suptitle('Histograms for some variables')
sns.histplot(datacc['price'], ax=ax1)
ax1.set_title('$Price$')
sns.histplot(datacc['year'], ax=ax2)
ax2.set_title('$Year$')
sns.histplot(datacc['kms'], ax=ax3)
ax3.set_title('$kms$')
#Segmentación del mercado basado en histogramas
# Out:
# Text(0.5, 1.0, '$kms$')

# %% [markdown]
# #### Boxplots

# %%
### Boxplot
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,5))
fig.suptitle('Boxplots for some variables')
sns.boxplot(data=datacc[['price']], ax=ax1)
sns.boxplot(data=datacc[['year']], ax=ax2)
sns.boxplot(data=datacc[['kms']], ax=ax3)
#Valores atipicos = °
# Out:
# <Axes: >

# %% [markdown]
# #### Ouliers treatment
# _https://www.statology.org/remove-outliers-python/_
# _https://towardsdatascience.com/a-complete-guide-for-detecting-and-dealing-with-outliers-bad26b1e92b6_
# _https://www.scribbr.com/statistics/outliers/_
# _https://www.statology.org/remove-outliers/_

# %%
# Z score to eliminate outliers of 'year' and 'kms'
from scipy import stats

#find absolute value of z-score for each observation of 'kms'
z2 = np.abs(stats.zscore(datacc['kms']))

#only keep rows in dataframe with all z-scores less than absolute value of 3
toremove = datacc.kms[(z2>3)].index
datacc = datacc.drop(toremove)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,5))
fig.suptitle('Boxplots for some variables')
sns.boxplot(data=datacc[['price']], ax=ax1)
sns.boxplot(data=datacc[['year']], ax=ax2)
sns.boxplot(data=datacc[['kms']], ax=ax3)
# Out:
# <Axes: >

# %%
# Histograms
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,6))
fig.suptitle('Histograms for some variables')
sns.histplot(datacc['price'], ax=ax1)
ax1.set_title('$Price$')
sns.histplot(datacc['year'], ax=ax2)
ax2.set_title('$Year$')
sns.histplot(datacc['kms'], ax=ax3)
ax3.set_title('$kms$')
# Out:
# Text(0.5, 1.0, '$kms$')

# %% [markdown]
# ### EDA (Exploratory Data Analysis)

# %% [markdown]
# #### Correlations

# %%
def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(15,15))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.2, annot=False, cbar_kws={"shrink": .95}
                )
    plt.show();

correlation_heatmap(X[['year', 'kms']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-70ad6e18f0cb> in <cell line: 10>()
#       8     plt.show();
#       9
# ---> 10 correlation_heatmap(X[['year', 'kms']])
#
# NameError: name 'X' is not defined

# %%
g = sns.PairGrid(X[['year', 'kms']])
g.map(sns.scatterplot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-3494f8bf022c> in <cell line: 1>()
# ----> 1 g = sns.PairGrid(X[['year', 'kms']])
#       2 g.map(sns.scatterplot)
#
# NameError: name 'X' is not defined

# %% [markdown]
# ## Modeling: machine learning

# %% [markdown]
# ### Libraries

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split as split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as MSE, r2_score
from sklearn.metrics import mean_absolute_error as MAE
import pickle

# %% [markdown]
# ### Data partitioning

# %%
#Variables Independientes / dividir variables
X = datacc.copy()
X = X.drop(['price'], axis=1)
print(X.shape)

#Variable a predecir
Y = pd.DataFrame()
Y = datacc['price']
print(Y.shape)
# Out:
# (419, 4)
# (419,)

# %%
# Data set normalization and partitioning
# Normalización a todas las variables independientes
sc = StandardScaler()
Xsc = sc.fit(X)
Xt = Xsc.transform(X)
Xt.shape
# Out:
# (419, 4)

# %%
X_train, X_test, y_train, y_test = split(Xt,Y,
                                         test_size=0.20, #porcentaje de evaluación
                                         random_state=42)

# %% [markdown]
# ### Multivariate lineal regression

# %%
# Define model and prediction
ols = LinearRegression()
model1 = ols.fit(X_train, y_train)
y_pred1 = model1.predict(X_test)

# %%
# accuracy check
# RMSE más cercano a 0 diferencia del valor de la predicción respecto a la realidad / margen de error no percentual
# R2 mas cercano a 1 porcentaje de exactitud
rmse = MSE(y_test, y_pred1, squared=False)
mae = MAE(y_test, y_pred1)
r2 = r2_score(y_test, y_pred1)
print("RMSE: %.2f" % rmse)
print("MAE: %.2f" % mae)
print("R2: %.2f" % r2)
# Out:
# RMSE: 4497056.49
# MAE: 3266823.60
# R2: 0.59

# %% [markdown]
# ### Light GBM
# https://www.analyticsvidhya.com/blog/2021/08/complete-guide-on-how-to-use-lightgbm-in-python/
# https://www.datatechnotes.com/2022/03/lightgbm-regression-example-in-python.html

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.11.4)

# %%
import lightgbm as lgb

# %%
# Hyperparameters
params = {
    'task': 'train',
    'boosting': 'gbdt',
    'objective': 'regression',
    'num_leaves': 10,
    'learning_rate': 0.05,
    'metric': {'l2','l1'},
    'header' : 'true',
    'verbose': 0
}

# laoding data
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# fitting the model
model2 = lgb.train(params,
                 train_set=lgb_train,
                 valid_sets=lgb_eval)
# Pred
y_pred2 = model2.predict(X_test)

# %%
# accuracy check
rmse = MSE(y_test, y_pred2, squared=False)
mae = MAE(y_test, y_pred2)
r2 = r2_score(y_test, y_pred2)
print("RMSE: %.2f" % rmse)
print("MAE: %.2f" % mae)
print("R2: %.2f" % r2)
# Out:
# RMSE: 4595564.06
# MAE: 3451932.63
# R2: 0.58

# %%
# visualizing in a plot
x_ax = range(len(y_test))
plt.figure(figsize=(12, 6))
plt.plot(x_ax, y_test, label="original")
plt.plot(x_ax, y_pred2, label="predicted")
plt.title("Original and predicted car prices")
plt.xlabel('X')
plt.ylabel('Price')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
# plotting feature importance
ax = lgb.plot_importance(model2, height=.5, title="LightGBM Feature Importance")

# %%
lgb.plot_tree(model2,figsize=(30,40))
# Out:
# <Axes: >

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model3 = RandomForestRegressor()
model3.fit(X_train, y_train)
y_pred3 = model3.predict(X_test)

# %%
# accuracy check
rmse = MSE(y_test, y_pred3, squared=False)
mae = MAE(y_test, y_pred3)
r2 = r2_score(y_test, y_pred3)
print("RMSE: %.2f" % rmse)
print("MAE: %.2f" % mae)
print("R2: %.2f" % r2)
# Out:
# RMSE: 4521338.23
# MAE: 3343545.32
# R2: 0.59

# %% [markdown]
# **Save the model**

# %%
with open('model3.pkl', 'wb') as f:
  pickle.dump(model3, f)

# %% [markdown]
# ### Xgboost regressor
# https://www.datatechnotes.com/2019/06/regression-example-with-xgbregressor-in.html

# %%
from sklearn.model_selection import cross_val_score, KFold
import xgboost as xgb
from sklearn.metrics import classification_report

# %%
#Define model
model4 = xgb.XGBRegressor(objective ='reg:squarederror',
                          booster='gbtree',
                          colsample_bytree = 1,
                          importance_type='gain',
                          learning_rate = 0.2,
                          max_depth = 5,
                          alpha = 5,
                          n_estimators = 200,
                          seed=123)

# %%
#Training
model4.fit(X_train, y_train)#,
#         eval_set=[(X_train, y_train), (X_test, y_test)], \
#         eval_metric='mlogloss', verbose=False)
# Out:
# XGBRegressor(alpha=5, base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None, colsample_bytree=1,
#              device=None, early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
#K-fold cross validation
scores = cross_val_score(model4, X_train, y_train, cv=10)
print("Mean cross-validation score: %.2f" % scores.mean())
# Out:
# Mean cross-validation score: 0.45

# %%
kfold = KFold(n_splits=10, shuffle=True)
kf_cv_scores = cross_val_score(model4, X_train, y_train, cv=kfold )
print("K-fold CV average score: %.2f" % kf_cv_scores.mean())
# Out:
# K-fold CV average score: 0.44

# %%
# Pred
y_pred4 = model4.predict(X_test)

# %%
# accuracy check
rmse = MSE(y_test, y_pred4, squared=False)
mae = MAE(y_test, y_pred4)
r2 = r2_score(y_test, y_pred4)
print("RMSE: %.2f" % rmse)
print("MAE: %.2f" % mae)
print("R2: %.2f" % r2)
# Out:
# RMSE: 5116932.06
# MAE: 3989011.50
# R2: 0.47

# %%
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="original")
plt.plot(x_ax, y_pred4, label="predicted")
plt.title("Car Prices: real vs. predicted")
plt.legend()
plt.show()
